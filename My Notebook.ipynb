# %%
# Render our plots inline
# %matplotlib inline

# Import several libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dataURL = 'http://vincentarelbundock.github.io/Rdatasets/csv/datasets/LakeHuron.csv'
data = pd.read_csv(dataURL)

# %%
plt.plot(data['time'], data['LakeHuron'])
plt.xlabel('Year')
plt.ylabel('Feet')
